# %%
from tensorflow.python.lib.io.file_io import FileIO as open_file
import subprocess
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %%bash
# gsutil ls gs://alex-s2t-test/adversarial/images/
# Out:
# gs://alex-s2t-test/adversarial/images/dataset/

# %%
all_images=subprocess.check_output('gsutil ls -r gs://alex-s2t-test/adversarial/images/**'.split(" ")).strip().split("\n")
len(all_images), all_images[0]
# Out:
# (13417,
#  'gs://alex-s2t-test/adversarial/images/dataset/AAAPistol/120px-Beretta92Centurion.jpg')

# %%
ds_content = [[x, x.split("/")[-2]] for x in all_images]

# %%
import pandas as pd

# %%
df = pd.DataFrame(ds_content, columns=["image","labels"])
df
# Out:
#                                                    image     labels
# 0      gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 1      gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 2      gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 3      gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 4      gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 5      gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 6      gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 7      gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 8      gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 9      gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 10     gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 11     gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# 12     gs://alex-s2t-test/adversarial/images/dataset/...  AAAPistol
# ...

# %%
df["labels"].value_counts()
# Out:
# KNIVES               3559
# airplanes             800
# Motorbikes            798
# AAAPistol             796
# BACKGROUND_Google     467
# Faces_easy            435
# Faces                 435
# watch                 239
# Leopards              200
# bonsai                128
# car_side              123
# ketch                 114
# chandelier            107
# hawksbill             100
# grand_piano            99
# brain                  98
# butterfly              91
# helicopter             88
# menorah                87
# trilobite              86
# starfish               86
# kangaroo               86
# ewer                   85
# sunflower              85
# buddha                 85
# scorpion               84
# laptop                 81
# ibis                   80
# llama                  78
# minaret                76
#                      ...
# barrel                 47
# pagoda                 47
# beaver                 46
# stapler                45
# ...

# %%
all_images[0].split("/")[-2]
# Out:
# 'AAAPistol'

# %%
with open_file("gs://alex-s2t-test/adversarial/datasets/original/data_set.csv", "w") as f:
    df.to_csv(f, index=False)
